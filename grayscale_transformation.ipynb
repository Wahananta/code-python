# %% [markdown]
# <a href="https://colab.research.google.com/github/Wahananta/code-python/blob/main/grayscale_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('bunga_merah.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
grayImg = cv2.cvtColor(np.array(img),cv2.COLOR_BGR2GRAY)
cv2_imshow(grayImg)
# Out:
# <PIL.Image.Image image mode=RGB size=728x455 at 0x7F6C48350C40>
# <PIL.Image.Image image mode=L size=728x455 at 0x7F6C48350C40>
