# %% [markdown]
# <a href="https://colab.research.google.com/github/Wahananta/code-python/blob/main/edge_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import canny
from skimage import data,morphology
from skimage.color import rgb2gray
import scipy.ndimage as nd
import cv2 
from google.colab.patches import cv2_imshow

# %%
plt.rcParams["figure.figsize"] = (12,8)
# %matplotlib inline

# %%
image1 = cv2.imread('rambu-lalu-lintas.jpg')

# %%
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7FA2654A1AC0>

# %%
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1000x667 at 0x7FA22DB28040>

# %%
edges = canny(img)
plt.imshow(edges, interpolation='gaussian')
plt.title('Canny detector')
# Out:
# Text(0.5, 1.0, 'Canny detector')

# %%
fill_im = nd.binary_fill_holes(edges)
plt.imshow(fill_im)
plt.title('Region Filling')
# Out:
# Text(0.5, 1.0, 'Region Filling')

# %%
from skimage.filters import sobel
elevation_map = sobel(img)
fig, ax = plt.subplots(figsize=(4, 3))
plt.imshow(elevation_map, cmap=plt.cm.gray, interpolation='nearest')
plt.axis('on')
plt.title('elevation_map')
# Text(0.5, 1.0, 'elevation_map')
# Out:
# Text(0.5, 1.0, 'elevation_map')
